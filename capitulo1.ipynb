# %% [markdown]
# Cadenas en Python
#
# En el vídeo, conociste otro tipo de datos estándar de Python, las cadenas. Recuerda que representan datos textuales. Para asignar la cadena 'DataCamp' a una variable company, ejecuta:
#
# company = 'DataCamp'
#
# También has aprendido a utilizar las operaciones + y * con cadenas. A diferencia de lo que ocurre con tipos numéricos como ints y floats, el operador + concatena cadenas, mientras que * concatena varias copias de una cadena. En este ejercicio, utilizarás las operaciones + y * sobre cadenas para responder a la siguiente pregunta. Ejecuta el siguiente código en el intérprete de comandos:
#
# object1 = "data" + "analysis" + "visualization"
# object2 = 1 * 3
# object3 = "1" * 3
#
# ¿Cuáles son los valores de object1, object2, y object3, respectivamente?

# %%
object1 = "data" + "analysis" + "visualization"
object2 = 1 * 3
object3 = "1" * 3

object1
object2
object3
# Out:
# '111'

# %% [markdown]
# Recapitulación de funciones incorporadas
#
# En el vídeo, Hugo examinó brevemente el comportamiento de retorno de las funciones incorporadas print() y str(). Aquí utilizarás ambas funciones y examinarás sus valores de retorno. Para este ejercicio se ha precargado una variable x. Ejecuta el código siguiente en la consola. Presta mucha atención a los resultados para responder a la pregunta que sigue.
#
#     Asigna str(x) a una variable y1: y1 = str(x)
#     Asigna print(x) a una variable y2: y2 = print(x)
#     Comprueba los tipos de las variables x, y1 y y2.
#
# ¿Cuáles son los tipos de x, y1 y y2?

# %% [markdown]
# Escribir una función sencilla
#
# En el último vídeo, Hugo describió los fundamentos de cómo definir una función. ¡Ahora escribirás tu propia función!
#
# Define una función, shout(), que simplemente imprima una cadena con tres signos de exclamación '!!!' al final. El código de la función square() que hemos escrito antes se encuentra a continuación. Puedes utilizarlo como patrón para definir shout().
#
# def square():
#     new_value = 4 ** 2
#     return new_value
#
# Ten en cuenta que el cuerpo de la función ya está sangrado 4 espacios por ti. Los cuerpos de las funciones deben sangrarse con un número coherente de espacios, y elegir 4 es lo habitual.
#
# Este curso toca muchos conceptos que puedes haber olvidado, así que si alguna vez necesitas un repaso rápido, ¡descarga la hoja de trucos de Python para la Ciencia de Datos y tenla a mano!

# %%
# Define the function shout
def shout():
    """Print a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = 'congratulations' + '!!!'

    # Print shout_word
    print(shout_word)

# Call shout
shout()
# Out:
# congratulations!!!

# %% [markdown]
# Funciones de un solo parámetro
#
# ¡Enhorabuena! ¡Has definido y llamado correctamente a tu propia función! Eso está muy bien.
#
# En el ejercicio anterior, definiste y llamaste a la función shout(), que imprimía una cadena concatenada con '!!!'. Ahora actualizarás shout(). Para ello, añadirás un parámetro para que pueda aceptar y procesar cualquier argumento de cadena que se le pase. Ten en cuenta también que shout(word), la parte de la cabecera que especifica el nombre de la función y el parámetro o parámetros, se conoce como la firma de la función. ¡Puede que encuentres este término en la naturaleza!

# %%
# Define shout with the parameter, word
def shout(word):
    """Print a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = word + '!!!'

    # Print shout_word
    print(shout_word)

# Call shout with the string 'congratulations'
shout('congratulations')
# Out:
# congratulations!!!

# %% [markdown]
# Funciones que devuelven valores únicos
#
# ¡Se te da muy bien! Prueba a modificar de nuevo la función shout() para que ahora devuelva un único valor en lugar de imprimir dentro de la función. Recuerda que la palabra clave return te permite devolver valores de las funciones. Se muestran partes de la función shout(), que escribiste anteriormente. Devolver valores suele ser más conveniente que imprimirlos porque, como has visto antes, una llamada a print() asignada a una variable tiene el tipo NoneType.

# %%
# Define shout with the parameter, word
def shout(word):
    """Return a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = word + '!!!'

    # Replace print with return
    return shout_word

# Pass 'congratulations' to shout: yell
yell = shout('congratulations')

# Print yell
print(yell)
# Out:
# congratulations!!!

# %% [markdown]
# Funciones con múltiples parámetros
#
# En la última clase, Hugo habló del uso de múltiples parámetros en la definición de funciones. Ahora vas a utilizar lo que has aprendido para modificar aún más la función shout(). Aquí modificarás shout() para que acepte dos argumentos. Se muestran partes de la función shout(), que escribiste anteriormente.

# %%
# Define shout with parameters word1 and word2
def shout(word1, word2):
    """Concatenate strings with three exclamation marks"""
    # Concatenate word1 with '!!!': shout1
    shout1 = word1 + '!!!'
    
    # Concatenate word2 with '!!!': shout2
    shout2 = word2 + '!!!'
    
    # Concatenate shout1 with shout2: new_shout
    new_shout = shout1 + shout2

    # Return new_shout
    return new_shout

# Pass 'congratulations' and 'you' to shout(): yell
yell = shout('congratulations','you')

# Print yell
print(yell)
# Out:
# congratulations!!!you!!!

# %% [markdown]
# Breve introducción a las tuplas
#
# Además de aprender sobre las funciones, ¡también has aprendido sobre las tuplas! Aquí practicarás lo que has aprendido sobre las tuplas: cómo construir, desempaquetar y acceder a los elementos de las tuplas. Recuerda cómo Hugo desempaquetó la tupla even_nums en el vídeo:
#
# a, b, c = even_nums
#
# Para este ejercicio se ha precargado una tupla de tres elementos llamada nums. Antes de completar el guion, realiza lo siguiente:
#
#     Imprime el valor de nums en el intérprete de comandos IPython. Observa los elementos de la tupla.
#     En el intérprete de comandos IPython, intenta cambiar el primer elemento de nums por el valor 2 haciendo una asignación: nums[0] = 2. ¿Qué ocurre?

# %%
nums = (3,4,6)

# Unpack nums into num1, num2, and num3
num1,num2,num3 = nums

# Construct even_nums
even_nums = 2,num2,num3

even_nums
# Out:
# (2, 4, 6)

# %% [markdown]
# Funciones que devuelven varios valores
#
# En el ejercicio anterior, construiste tuplas, asignaste tuplas a variables y descomprimiste tuplas. Aquí devolverás varios valores de una función mediante tuplas. Actualicemos ahora nuestra función shout() para que devuelva varios valores. En lugar de devolver solo una cadena, devolveremos dos cadenas con la cadena !!! concatenada a cada una.
#
# Observa que la declaración de retorno return x, y tiene el mismo resultado que return (x, y): ¡la primera en realidad empaqueta x y y en una tupla bajo el capó!

# %%
# Define shout_all with parameters word1 and word2
def shout_all(word1, word2):
    """Return a tuple of strings"""
    # Concatenate word1 with '!!!': shout1
    shout1 = word1 + '!!!'
    
    # Concatenate word2 with '!!!': shout2
    shout2 = word2 + '!!!'
    
    # Construct a tuple with shout1 and shout2: shout_words
    shout_words = shout1,shout2

    # Return shout_words
    return shout_words

# Pass 'congratulations' and 'you' to shout_all(): yell1, yell2
yell1,yell2 = shout_all('congratulations','you')

# Print yell1 and yell2
print(yell1)
print(yell2)
# Out:
# congratulations!!!
# you!!!

# %%
import pandas as pd

# %% [markdown]
# Unirlo todo (1)
#
# Ya has probado a escribir tus propias funciones en los ejercicios anteriores. Has aprendido a añadir parámetros a tus propias definiciones de funciones, a devolver un valor o varios valores con tuplas y a llamar a las funciones que has definido.
#
# En este ejercicio y en el siguiente, reunirás todos estos conceptos y los aplicarás a un sencillo problema de ciencia de datos. Cargarás un conjunto de datos y desarrollarás funcionalidades para extraer información sencilla de los datos.
#
# Para este ejercicio, tu objetivo es recordar cómo cargar un conjunto de datos en un DataFrame. El conjunto de datos contiene datos de Twitter e iterarás sobre las entradas de una columna para construir un diccionario en el que las claves son los nombres de los idiomas y los valores son el número de tweets en el idioma dado. El archivo tweets.csv está disponible en tu directorio actual.
#
# Ten en cuenta que se trata de datos reales de Twitter y, como tales, siempre existe el riesgo de que contengan blasfemias u otros contenidos ofensivos (en este ejercicio y en los siguientes que también utilicen datos reales de Twitter).

# %%
# Import pandas
import pandas as pd

# Import Twitter data as DataFrame: df
df = pd.read_csv('tweets.csv')

# Initialize an empty dictionary: langs_count
langs_count = {}

# Extract column from DataFrame: col
col = df['lang']

# Iterate over lang column in DataFrame
for entry in col:

    # If the language is in langs_count, add 1 
    if entry in langs_count.keys():
        langs_count[entry] += 1
    # Else add the language to langs_count, set the value to 1
    else:
        langs_count[entry] = 1

# Print the populated dictionary
print(langs_count)
# Out:
# {'en': 97, 'et': 1, 'und': 2}

# %% [markdown]
# Unirlo todo (2)
#
# ¡Buen trabajo! Ahora has definido la funcionalidad para iterar sobre las entradas de una columna y construir un diccionario con claves los nombres de los idiomas y valores el número de tuits en el idioma dado.
#
# En este ejercicio, definirás una función con la funcionalidad que desarrollaste en el ejercicio anterior, devolverás el diccionario resultante desde dentro de la función y llamarás a la función con los argumentos adecuados.
#
# Para tu comodidad, el paquete de pandas se ha importado como pd y el archivo 'tweets.csv' se ha importado en la variable tweets_df.

# %%
tweets_df = pd.read_csv('tweets.csv')

# Define count_entries()
def count_entries(df, col_name):
    """Return a dictionary with counts of 
    occurrences as value for each key."""

    # Initialize an empty dictionary: langs_count
    langs_count = {}
    
    # Extract column from DataFrame: col
    col = df[col_name]
    
    # Iterate over lang column in DataFrame
    for entry in col:

        # If the language is in langs_count, add 1
        if entry in langs_count.keys():
            langs_count[entry] += 1
        # Else add the language to langs_count, set the value to 1
        else:
            langs_count[entry] = 1

    # Return the langs_count dictionary
    return langs_count

# Call count_entries(): result
result = count_entries(tweets_df,'lang')

# Print the result
print(result)
# Out:
# {'en': 97, 'et': 1, 'und': 2}
